# %%
from __future__ import print_function, division

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import requests

url = 'http://www.the-numbers.com/home-market/dvd-sales/2015'

response = requests.get(url)

# %%
from bs4 import BeautifulSoup

# %%
page = response.text
soup = BeautifulSoup(page)

# %%
movie_list = soup.find("table")
movie_data = []

header = ['Rank','Units Sold','Total Consumer Spending']
for row in movie_list.findAll("tr"):
    row_dict={}
    for i,cell in enumerate(row.findAll("td",{ "class" : "data" })):
        row_dict[header[i]] = cell.find(text=True)
    
    #link = row.find("td")
    #link = row.find("td").findAll("a")
    #if not link.find({'rel':'nofollow'}):
    #    row_dict['Title']=link.text
    #if link.find("a", {"href":''}) and (not link.find("a",{"rel":"nofollow"})):
    #    row_dict['Title'] = link.text
    
    #if link:
        #if (not link.find("td", {"class": "data"})) & (not link.find("a",{"rel":"nofollow"})):
            #row_dict['Title'] = link.text
        #if link.find("a",{"rel":"nofollow"}):
        #    row_dict['Buy'] = link.find("a",{"rel":"nofollow"}).text
    movie_data.append(row_dict)
    
movies_df = pd.DataFrame(movie_data)
movies_df.dropna()
# Out:
#     Rank Total Consumer Spending Units Sold
# 1      1             $45,746,016  2,630,395
# 2      2             $34,785,200  2,556,881
# 3      3             $41,878,119  2,553,834
# 4      4             $38,959,156  2,333,427
# 5      5             $30,439,520  2,298,058
# 6      6             $32,759,231  2,232,008
# 7      7             $31,716,342  2,213,489
# 8      8             $28,634,303  2,059,630
# 9      9             $25,587,390  1,758,886
# 10    10             $22,955,309  1,510,576
# 11    11             $23,146,655  1,486,675
# 12    12             $14,920,545  1,319,464
# 13    13             $18,584,911  1,296,584
# 14    14             $20,450,086  1,246,174
# 15    15             $16,557,083  1,241,292
# 16    16             $23,834,268  1,200,070
# 17    17             $11,522,474  1,161,375
# 18    18             $15,610,828  1,101,490
# 19    19             $16,086,992  1,079,954
# 20    20             $16,112,192  1,069,150
# ...

# %%
import html5lib
import pandas as pd
df=pd.read_html('http://www.the-numbers.com/home-market/dvd-sales/2015')

# %%
url='http://www.the-numbers.com/box-office-chart/weekend/2016/09/02'
response2 = requests.get(url)

# %%
soup2 = BeautifulSoup(response2.text)

# %%
movie_list2 = soup2.find("table", {'border':'0'})
movie_data2 = []
header = ['Rank','NumWeeks','Movie','Distributor','Gross','Change','Thtrs', 'PerThtr','TotalGross','Days']
for row in movie_list2.findAll("tr"):
    row_dict={}
    for i,cell in enumerate(row.findAll("td")):
        row_dict[header[i]]=cell.find(text=True)
    movie_data2.append(row_dict)
    
movies_df2 = pd.DataFrame(movie_data2)
movies_df2.dropna()
# Out:
#     Change    Days            Distributor        Gross  \
# 1     -40%      10          Sony Pictures  $15,833,223
# 2     -19%      31           Warner Bros.   $9,910,256
# 3     -19%      17         Focus Features   $6,375,278
# 4     -15%      24            Walt Disney   $6,349,807
# 5     -31%      24          Sony Pictures   $5,193,461
# 6     -31%      17           Warner Bros.   $4,812,634
# 7     -14%      38      STX Entertainment   $4,766,501
# 8                3            Walt Disney   $4,765,838
# 9     +25%      24              Lionsgate   $4,440,573
# 10    -40%      10              Lionsgate   $4,440,321
# 11    -23%      38              Universal   $3,962,600
# 12               3              Lionsgate   $3,676,235
# 13     -9%      59              Universal   $3,534,925
# 14    +10%      45     Paramount Pictures   $2,477,309
# 15    -52%      17     Paramount Pictures   $2,201,643
# 16    -29%      24     Paramount Pictures   $2,109,083
# ...

# %%
from __future__ import print_function, division
from bs4 import BeautifulSoup
import requests
from time import sleep
import pandas as pd
import numpy as np
import html5lib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime
from time import sleep
import pickle

for k,v in get_genre_links():
    print("Scraping the " + k + "movies...")
    movie_scrape(k,v)

def movie_scrape(genre,url):
    movie_data=[]
    soup = BeautifulSoup(requests.get(url).text, 'html5lib')
    movie_list = soup.find('table')
    header = ['Movie', 'Release Date', 'Distributor', 'MPAA Rating', 'Domestic Gross', 'Inflation-Adjusted Gross']
    for row in movie_list.findAll("tr"):
        all_tables = row.findAll('td')
        if len(all_tables)>0:
            cell = all_tables[0]
            x = cell.find('a')
            if x:
                movie = base_url + x['href']
        row_dict={}
        for i,cell in enumerate(row.findAll("td")):
            row_dict[header[i]]=cell.find(text=True)
        row_dict['Genre'] = genre
        sleep(0.1)
        row_dict['Running Time'], row_dict['Production Budget'], row_dict['International Box Office'], row_dict['Domestic DVD Sales'], row_dict['Domestic Blu-ray Sales'] = get_more_movie_info(movie)
        movie_data.append(row_dict)

    movies_df = pd.DataFrame(movie_data)
    movies_df.dropna()
    movies_df.drop(movies_df.index[[-1]], inplace=True)
    movies_df['Release Date'] = movies_df['Release Date'].astype('unicode')
    movies_df = movies_df[movies_df['Release Date'] != 'nan']

    movies_df['Release Date'] = movies_df['Release Date'].apply(lambda x: x.encode('ascii', 'ignore'))
    movies_df['Release Date'] = pd.to_datetime(movies_df['Release Date'], format = '%b%d,%Y')
    movies_df['Domestic Gross'] = movies_df['Domestic Gross'].apply(lambda x: int(x.replace('$', '').replace(',', '')))
    movies_df['Inflation-Adjusted Gross'] = movies_df['Inflation-Adjusted Gross'].apply(lambda x: int(x.replace('$', '').replace(',', '')))
    movies_df.to_pickle('results'+url+'.pkl')
    sleep(0.1)

# %%
def get_genre_links(url='http://www.the-numbers.com/market/genres'):
    base_url = 'http://www.the-numbers.com'
    soup = BeautifulSoup(requests.get(url).text, 'html5lib')
    table=soup.find('table')
    movies_by_genre_dict={}
    for link in table.find_all('a'):
        movies_by_genre_dict[link.text] = base_url + link.get('href').replace('market','movies')
    return movies_by_genre_dict

# %%
movies_by_genre_dict = get_genre_links()
movies_by_genre_dict
# Out:
# {u'Action': u'http://www.the-numbers.com/movies/genre/Action',
#  u'Adventure': u'http://www.the-numbers.com/movies/genre/Adventure',
#  u'Black Comedy': u'http://www.the-numbers.com/movies/genre/Black-Comedy',
#  u'Comedy': u'http://www.the-numbers.com/movies/genre/Comedy',
#  u'Concert/Performance': u'http://www.the-numbers.com/movies/genre/Concert-or-Performance',
#  u'Documentary': u'http://www.the-numbers.com/movies/genre/Documentary',
#  u'Drama': u'http://www.the-numbers.com/movies/genre/Drama',
#  u'Educational': u'http://www.the-numbers.com/movies/genre/Educational',
#  u'Horror': u'http://www.the-numbers.com/movies/genre/Horror',
#  u'Multiple Genres': u'http://www.the-numbers.com/movies/genre/Multiple-Genres',
#  u'Musical': u'http://www.the-numbers.com/movies/genre/Musical',
#  u'Reality': u'http://www.the-numbers.com/movies/genre/Reality',
#  u'Romantic Comedy': u'http://www.the-numbers.com/movies/genre/Romantic-Comedy',
# ...

# %%
def get_movie_value(soup, field_name):
    '''Grab a value from boxofficemojo HTML
    
    Takes a string attribute of a movie on the page and
    returns the string in the next sibling object
    (the value for that attribute)
    or None if nothing is found.
    '''
    obj = soup.find(text=re.compile(field_name))
    if not obj: 
        return None
    # this works for most of the values
    next = obj.findNext()
    if next:
        return next.text 
    else:
        return None

# %%
print('Production\xa0Budget:')
# Out:
# Production�Budget:

# %%
import re
def get_more_movie_info(url):
    ''' Extract the running time, production budget
    international box office, domestic DVD sales, and
    domestic Blu-ray sales'''
    soup = BeautifulSoup(requests.get(url).text, 'html5lib')
    return int(get_movie_value(soup,'Running Time:').replace(' minutes', '')), int(get_movie_value(soup,'Production.Budget').replace('$', '').replace(',', '')), int(get_movie_value(soup,'International Box Office').replace('$', '').replace(',', '')), int(get_movie_value(soup,'Domestic DVD Sales').replace('$', '').replace(',', '')), int(get_movie_value(soup,'Domestic Blu-ray Sales').replace('$', '').replace(',', ''))

# %%
content = '''\
<tr>
<td id="freistoesse">Giraffe</td>
<td>14</td>
<td>7</td>
</tr>'''
soup5 = BeautifulSoup(content)
l=[]
for td in soup5.find('td', text='Giraffe').parent.find_all('td'):
    l.append(td.text)

# %%
l
# Out:
# [u'Giraffe', u'14', u'7']

# %%
def get_movie_url_list(soup):
#    soup = BeautifulSoup(requests.get(url).text, 'html5lib')
    movie_list = soup.find('table')
    movie_url_list = []
    for row in movie_list.findAll("tr"):
        all_tables = row.findAll('td')
        if len(all_tables)>0:
            cell = all_tables[0]
            x = cell.find('a')
            if x:
                movie = base_url + x['href']
                movie_url_list.append(movie)
    return movie_url_list

# %%
base_url = 'http://www.the-numbers.com'
url = 'http://www.the-numbers.com/movies/genre/Educational'
movie_url_list2 = []
movie_data=[]
soup10 = BeautifulSoup(requests.get(url).text, 'html5lib')
movie_list = soup10.find('table')
header = ['Movie', 'Release Date', 'Distributor', 'MPAA Rating', 'Domestic Gross', 'Inflation-Adjusted Gross']
    
# The following for loop will extract the link URL for each movie in the list, where the other info is located
for row in movie_list.findAll("tr"):
    all_td = row.findAll('td')
    if len(all_td)>0:
        cell = all_td[0]
        x = cell.find('a')
        if x:
            movie = base_url + x['href']
            movie_url_list2.append(movie)

# %%
movie_url_list2[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-453-390606fd2519> in <module>()
# ----> 1 movie_url_list2[1]
#
# IndexError: list index out of range

# %%
import re
def get_more_movie_info2(url):
    ''' Extract the running time, production budget
    international box office, domestic DVD sales, and
    domestic Blu-ray sales'''
    soup = BeautifulSoup(requests.get(url).text, 'html5lib')
    return get_movie_value(soup,'Running Time:'), get_movie_value(soup,'Production.Budget'), get_movie_value(soup,'International Box Office'), get_movie_value(soup,'Domestic DVD Sales'), get_movie_value(soup,'Domestic Blu-ray Sales')

# %%
print(get_more_movie_info2('http://www.the-numbers.com/movie/Kang-rinpoche#tab=summary'))
# Out:
# (u'115 minutes', None, None, None, None)

# %%
#def movie_scrape(genre,url):
movie_data=[]
soup20 = BeautifulSoup(requests.get('http://www.the-numbers.com/movies/genre/Action').text, 'html5lib')
movie_list = soup20.find('table')
movie_url_list = []
base_url = 'http://www.the-numbers.com'
header = ['Movie', 'Release Date', 'Distributor', 'MPAA Rating', 'Domestic Gross', 'Inflation-Adjusted Gross']
i=0
for row in movie_list.findAll("tr"):
    #all_tables = row.findAll('td')
    #if len(all_tables)>0:
    #    cell = all_tables[0]
    #    x = cell.find('a')
    #    if x:
    #        movie_url_list.append(base_url + x['href'])
    row_dict={}
    for j,cell in enumerate(row.findAll("td")):
        #print("movie %d" %i)
        row_dict[header[j]]=cell.find(text=True)
        print(i,j)
    i += 1
    #row_dict['Running Time'], row_dict['Production Budget'], row_dict['International Box Office'], row_dict['Domestic DVD Sales'], row_dict['Domestic Blu-ray Sales'] = get_more_movie_info2(movie)
    #movie_data.append(row_dict)

#movies_df = pd.DataFrame(movie_data)
#movies_df.dropna()
#movies_df.drop(movies_df.index[[-1]], inplace=True)
#movies_df['Release Date'] = movies_df['Release Date'].astype('unicode')
#movies_df = movies_df[movies_df['Release Date'] != 'nan']

#movies_df['Release Date'] = movies_df['Release Date'].apply(lambda x: x.encode('ascii', 'ignore'))
#movies_df['Release Date'] = pd.to_datetime(movies_df['Release Date'], format = '%b%d,%Y')
#movies_df['Domestic Gross'] = movies_df['Domestic Gross'].apply(lambda x: int(x.replace('$', '').replace(',', '')))
#movies_df['Inflation-Adjusted Gross'] = movies_df['Inflation-Adjusted Gross'].apply(lambda x: int(x.replace('$', '').replace(',', '')))
# Out:
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4
# 1 5
# 2 0
# 2 1
# 2 2
# 2 3
# 2 4
# 2 5
# 3 0
# 3 1
# 3 2
# 3 3
# 3 4
# 3 5
# 4 0
# 4 1
# 4 2
# 4 3
# 4 4
# 4 5
# 5 0
# 5 1
# 5 2
# 5 3
# 5 4
# 5 5
# 6 0
# 6 1
# 6 2
# 6 3
# 6 4
# 6 5
# 7 0
# 7 1
# 7 2
# 7 3
# 7 4
# 7 5
# 8 0
# 8 1
# 8 2
# 8 3
# 8 4
# 8 5
# 9 0
# 9 1
# 9 2
# 9 3
# 9 4
# 9 5
# 10 0
# 10 1
# 10 2
# 10 3
# 10 4
# 10 5
# 11 0
# 11 1
# 11 2
# 11 3
# 11 4
# 11 5
# 12 0
# 12 1
# 12 2
# 12 3
# 12 4
# 12 5
# 13 0
# 13 1
# 13 2
# 13 3
# 13 4
# 13 5
# 14 0
# 14 1
# 14 2
# 14 3
# 14 4
# 14 5
# 15 0
# 15 1
# 15 2
# 15 3
# 15 4
# 15 5
# 16 0
# 16 1
# 16 2
# 16 3
# 16 4
# 16 5
# 17 0
# 17 1
# 17 2
# 17 3
# 17 4
# 17 5
# 18 0
# 18 1
# 18 2
# 18 3
# 18 4
# 18 5
# 19 0
# 19 1
# 19 2
# 19 3
# 19 4
# 19 5
# 20 0
# 20 1
# 20 2
# 20 3
# 20 4
# 20 5
# 21 0
# 21 1
# 21 2
# 21 3
# 21 4
# 21 5
# 22 0
# 22 1
# 22 2
# 22 3
# 22 4
# 22 5
# 23 0
# 23 1
# 23 2
# 23 3
# 23 4
# 23 5
# 24 0
# 24 1
# 24 2
# 24 3
# 24 4
# 24 5
# 25 0
# 25 1
# 25 2
# 25 3
# 25 4
# 25 5
# ...

# %%
def test():
    soup8 = BeautifulSoup(requests.get('http://www.the-numbers.com/movie/Demon-(2016)#tab=box-office').text, 'html5lib')
    movie_list = soup8.findAll('table')
    for table in movie_list:
        for row in table.findAll("tr"):
            x = row.find('a', href=re.compile('/box-office-chart/weekend/'))
            if x:
                y = x.findNext()
                if y:
                    z = y.findNext()
                    if z:
                        return z.text
                    else:
                        return None
                else:
                    return None
#            else:
#                return None
#    return None

# %%
print(test())
# Out:
# $13,023

# %%
print(len(movie_list.findAll("tr")))
#movies_df
# Out:
# 1244

# %%
import pickle
x=3

# %%
x.to_pickle('results.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-468-3be5c52620f6> in <module>()
# ----> 1 x.to_pickle('results.pkl')
#
# AttributeError: 'int' object has no attribute 'to_pickle'

# %%
d=dict()
x='hello'
d['a']=[1,2,3]
d['b']=[1,2,3]
df = pd.DataFrame(d)
df.to_pickle('Movie'+x+'.pkl')

# %%
df
# Out:
#    a  b
# 0  1  1
# 1  2  2
# 2  3  3

# %%
romantic = pd.read_pickle("resultsRomantic Comedy.pkl")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-476-8c09588e36bb> in <module>()
# ----> 1 romantic = pd.read_pickle("resultsRomantic Comedy.pkl")
#
# //anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in read_pickle(path)
#      63
#      64     try:
# ---> 65         return try_read(path)
#      66     except:
#      67         if PY3:
#
# //anaconda/lib/python2.7/site-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      60             except:
#      61                 with open(path, 'rb') as fh:
# ---> 62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#      64     try:
#
# //anaconda/lib/python2.7/site-packages/pandas/compat/pickle_compat.pyc in load(fh, encoding, compat, is_verbose)
#     115         up.is_verbose = is_verbose
#     116
# --> 117         return up.load()
#     118     except:
# ...

# %%
romantic
# Out:
#     Distributor  Domestic Blu-ray Sales  Domestic DVD Sales  Domestic Gross  \
# 1  Icarus Films                     NaN                 NaN           24666
#
#          Genre  Inflation-Adjusted Gross  International Box Office  \
# 1  Educational                     24666                       NaN
#
#   MPAA Rating          Movie  Production Budget Release Date Running Time
# 1   Not Rated  Kang rinpoche                NaN   2016-05-13  115 minutes

# %%
y='vince'
x='reuslts'+'_'+y[:3]
print(x)
# Out:
# reuslts_vin

# %%
from bs4 import BeautifulSoup
import requests
url = 'http://www.the-numbers.com/movie/Rambo#tab=summary'
soup20 = BeautifulSoup(requests.get(url).text, 'html5lib')
x = soup20.find('td', {"class" : "data sum"})
if x:
    print(x.text)
else:
    print('Nope.')
# Out:
# $69,460,426

# %%
def get_more_movie_info3(url):
    soup = BeautifulSoup(requests.get(url).text, 'html5lib')
    x = soup.find('td', {"class" : "data sum"})
    if x:
        y = x.text
    else:
        y = None
    return y

# %%
print(get_more_movie_info3('http://www.the-numbers.com/movie/Kang-rinpoche#tab=summary'))
# Out:
# None

# %%
obj = soup.find(text=re.compile(field_name))
    if not obj: 
        return None
    # this works for most of the values
    next = obj.findNext()
    if next:
        return next.text 
    else:
        return None

# %%
soup7 = BeautifulSoup(requests.get('http://www.the-numbers.com/movie/Mothers-Day-(2016)#tab=box-office').text, 'html5lib')

#x = soup7.findAll('table')
#for row in x.findAll("tr"):
#    print(row)
#     all_td = row.findAll('td')

y = soup7.findAll('td')
x = y.find('a', href=re.compile('/box-office-chart/weekend/'))
# if x:
#     y = x.findNext()
#     if y:
#         z = y.findNext()
#         if z:
#             print(z.text)
#         else:
#             print(None)
#     else:
#         print(None)
# else:
#     print(None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-505-1980c9b44487> in <module>()
#       7
#       8 y = soup7.findAll('td')
# ----> 9 x = y.find('a', href=re.compile('/box-office-chart/weekend/'))
#      10 # if x:
#      11 #     y = x.findNext()
#
# AttributeError: 'ResultSet' object has no attribute 'find'
